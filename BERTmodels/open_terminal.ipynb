# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
# !pip install pytorch-pretrained-bert
# !pip install transformers
# !pip install datasets
# !pip install emoji

# %% [markdown]
# open the terminal and enter to files directory:
#
#
#
# ```
# cd '/content/drive/MyDrive/Thesis project/Thesis/BERTmodels'
# ```

# %%
cd '/content/drive/MyDrive/Thesis project/Thesis/BERTmodels'
# Out:
# /content/drive/MyDrive/Thesis project/Thesis/BERTmodels

# %%
#!python runBERTmodels.py  --datasets "SARC_hot_topics_with_worsen_from_balanced_topic.csv SARC_hot_topics_test.csv SARC_balanced_topics_test2.csv SARC_random_test.csv semEval_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
#!python runBERTmodels.py  --datasets "SARC_balanced_topics_with_improve_from_SARC_hot_topic.csv SARC_hot_topics_test.csv SARC_balanced_topics_test2.csv SARC_random_test.csv semEval_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
#!python runBERTmodels.py  --datasets "balancedSemEval2022_train.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv preprocess_semEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
#!python runBERTmodels.py  --datasets "SARC_hot_topics_train.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csvpreprocess_semEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
#!python runBERTmodels.py  --datasets "SARC_balanced_topics_train.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv preprocess_semEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
#!python runBERTmodels.py  --datasets "SARC_random_train.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv preprocess_semEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
#!python runBERTmodels.py  --datasets "preprocess_semEval2022_train.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv SemEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
#!python runBERTmodels.py  --datasets "preprocess_semEval2022dataset_aug_with_RM4.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv SemEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
#!python runBERTmodels.py  --datasets "preprocess_semEval2022dataset_aug_with_random_RM2.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv SemEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
# !python runBERTmodels.py  --datasets "semEval2022_aug_with_tox.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv preprocess_semEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"
# !python runBERTmodels.py  --datasets "semEval2022_aug_with_iro.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv preprocess_semEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
# !python runBERTmodels.py  --datasets "SARC_balanced_topics_aug_with_hot_topics.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv preprocess_semEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"

# %%
# !python runBERTmodels.py  --datasets "semEval2022_aug_with_hot_topics.csv SARC_hot_topics_test.csv SARC_balanced_topics_test.csv SARC_random_test.csv preprocess_semEval2022_test.csv balancedSemEval2022_test.csv" #--output_model_dir "/content/drive/MyDrive/Thesis project/Thesis/BERTmodels/savedModels"
